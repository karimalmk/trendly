# %%
import yfinance

info = yfinance.Ticker("^IXIC").info
quote_type = info["quoteType"]
print(info)
# Out:
# {'maxAge': 86400, 'priceHint': 2, 'previousClose': 23581.145, 'open': 23941.775, 'dayLow': 23628.824, 'dayHigh': 23946.232, 'regularMarketPreviousClose': 23581.145, 'regularMarketOpen': 23941.775, 'regularMarketDayLow': 23628.824, 'regularMarketDayHigh': 23946.232, 'volume': 9879772000, 'regularMarketVolume': 9879772000, 'averageVolume': 9425295468, 'averageVolume10days': 10828073000, 'averageDailyVolume10Day': 10828073000, 'bid': 0.0, 'ask': 0.0, 'bidSize': 0, 'askSize': 0, 'fiftyTwoWeekLow': 14784.03, 'fiftyTwoWeekHigh': 24019.99, 'allTimeHigh': 24019.99, 'allTimeLow': 54.87, 'fiftyDayAverage': 22485.463, 'twoHundredDayAverage': 19995.525, 'currency': 'USD', 'tradeable': False, '52WeekChange': 30.500471, 'quoteType': 'INDEX', 'symbol': '^IXIC', 'language': 'en-US', 'region': 'US', 'typeDisp': 'Index', 'quoteSourceName': 'Delayed Quote', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'marketState': 'CLOSED', 'regularMarketChangePercent': 0.60986227, 'regularMarketPrice':
# ...
